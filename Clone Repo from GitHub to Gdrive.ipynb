# %% [markdown]
# # Clone Repo from GitHub to Gdrive
# For Colab Notebooks <br>
# <br>
# 1- Create the repository en Github <br>
# 2- Create the token <br>
#    https://github.com/settings/apps <br>
# 3- Clone Repo from GitHub to Gdrive <br>
#
# Run only once time just to Clone the repository on gdrive

# %% [markdown]
# # Gdrive mount it

# %%
# gdrive mount it
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %% [markdown]
# # Set gdrive directory

# %%
#gdrive_path = "/content/drive/MyDrive/Colab\ Notebooks/Codelab/"
gdrive_path = "/content/drive/MyDrive/Colab\ Notebooks/"
print(gdrive_path)
# %cd {gdrive_path}
# %ls {gdrive_path}

# %% [markdown]
# # GitHub repo id

# %%
#GitHub repo id
GIT_EMAIL = "your email"
GIT_USERNAME = "your user name"
GIT_TOKEN = "your token"     
GIT_REPOSITORY = "your repository"
GIT_PATH = "https://"+GIT_TOKEN+"@github.com/"+GIT_USERNAME+"/"+GIT_REPOSITORY+".git"
print(GIT_PATH)

# %% [markdown]
# # Clone Repo

# %%
#Clone Repo
#git clone https://{GIT_TOKEN}@github.com/{GIT_USERNAME}/{GIT_REPOSITORY}
# !git clone {GIT_PATH}

# %% [markdown]
# #Confirm repo is on gdrive

# %%
#List repo
gdrive_path_repo = "/content/drive/MyDrive/Colab\ Notebooks/"+GIT_REPOSITORY
# !ls {gdrive_path_repo}
