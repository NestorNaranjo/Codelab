# %% [markdown]
# # **Publish Colab to GitHub**
#
# Publish your local to Github  1111 <br>
# <BR>
# https://github.com/NestorNaranjo/Codelab

# %% [markdown]
# # GitHub repo id

# %%
#GitHub repo id
GIT_EMAIL = "your email"
GIT_USERNAME = "your usernama"
GIT_TOKEN = "token"     
GIT_REPOSITORY = "your repo"
GIT_PATH = "https://"+GIT_TOKEN+"@github.com/"+GIT_USERNAME+"/"+GIT_REPOSITORY+".git"
print(GIT_PATH)

# %% [markdown]
# # Gdrive mount it

# %%
# gdrive mount it
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %% [markdown]
# # Set Gdrive directory

# %%
#gdrive_path = "/content/drive/MyDrive/Colab\ Notebooks/"
gdrive_path = "/content/drive/MyDrive/Colab\ Notebooks/"+GIT_REPOSITORY+"/"
print(gdrive_path)
#!ls {gdrive_path}
# %cd {gdrive_path}
# %ls {gdrive_path}

# %% [markdown]
# # Git status

# %%
#Git status
# !git status

# %% [markdown]
# # Initialize git in a non-git repository

# %%
# !git config user.email {GIT_EMAIL}
# !git config user.name {GIT_USERNAME}
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Colab Notebooks/Codelab/.git/

# %% [markdown]
# #Add Files

# %%
#Add Files
# !git add --all

# %% [markdown]
# #Git commit

# %%
#Git commit publish files to github
MSG = "Added a files to "+ GIT_REPOSITORY +" repo"
#print(MSG )
# !git commit -m Colab

# %% [markdown]
# #Git status

# %%
#Git status
# !git status

# %% [markdown]
# #git push / pull
# "git push" to publish your local commits

# %%
print(GIT_PATH)
#!git pull {GIT_PATH}
# !git push {GIT_PATH}
