# %% [markdown]
# # Colab to GitHub
#
# Publish your local to Github <br>
# <BR>
# https://github.com/NestorNaranjo/Codelab

# %% [markdown]
# # Git status

# %%
#Git status
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %% [markdown]
# # GitHub repo id

# %%
#GitHub repo id
GIT_EMAIL = "nestor.a.naranjo@gmail.com"
GIT_USERNAME = "NestorNaranjo"
GIT_TOKEN = "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"     
GIT_REPOSITORY = "Codelab"
GIT_PATH = "https://"+GIT_TOKEN+"@github.com/"+GIT_USERNAME+"/"+GIT_REPOSITORY+".git"
print(GIT_PATH)
# Out:
# https://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@github.com/NestorNaranjo/Codelab.git

# %% [markdown]
# # gdrive mount it

# %%
# gdrive mount it
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Set gdrive directory

# %%
#gdrive_path = "/content/drive/MyDrive/Colab\ Notebooks/"
gdrive_path = "/content/drive/MyDrive/Colab\ Notebooks/"+GIT_REPOSITORY+"/"
#print(gdrive_path)
#!ls {gdrive_path}
# %cd {gdrive_path}
# %ls {gdrive_path}
# Out:
# /content/drive/MyDrive/Colab Notebooks/Codelab
# 'Clone Repo from GitHub to Gdrive.ipynb'   README.md
# 'Publish Colab to GitHub.ipynb'

# %% [markdown]
# # Initialize git in a non-git repository

# %%
# !git config user.email {GIT_EMAIL}
# !git config user.name {GIT_USERNAME}
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Colab Notebooks/Codelab/.git/

# %% [markdown]
# #Add Files

# %%
#Add Files
#!git add temp-plot.html
#!git add 'Colab to GitHub.ipynb'
# !git add --all

# %% [markdown]
# #Git commit

# %%
#Git commit
#Git commit changes
msg = "Added a files to the "+ GIT_REPOSITORY +" repo"
#print(msg)
# !git commit -a -m "Added a files to the " {GIT_REPOSITORY} "  repo"
#!git commit -m "Files Added"
# Out:
# [main 6d99aaf] Files Added
#  1 file changed, 1 insertion(+)
#  create mode 100644 Publish Colab to GitHub.ipynb

# %% [markdown]
# #Git status

# %%
#Git status
# !git status
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %% [markdown]
# #Git push
# "git push" to publish your local commits

# %%
# !git push
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 2.30 KiB | 587.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0)
# To https://github.com/NestorNaranjo/Codelab.git
#    ca76234..6d99aaf  main -> main
